# %% [markdown]
# # Creating a Classifier to Classify the type of Sport using Computer Vision
#
# *by: Dipanshu Gupta.*
#
# As part of exercise in FastAI course v3 by Jeremy Howard. Data set built using Google Images with inspiration from [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/).

# %% [markdown]
# `Note:` You probably need a GPU to run this program. I ran this on GCP (Google Cloud Platform).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling.
#
# We can also limit our results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now we must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. This is where we will paste the JavaScript commands.
#
# We need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload URLs file into them.

# %% [markdown]
# We create directories in our current directory for different sport and download images in them from the URLs we generated above. Choose an appropriate name for your labeled images.

# %%
path = Path('data/sports')

# %%
classes = ['badminton','baseball','basketball', 'cricket', 'football', 'golf', 'hockey', 'squash', 'swimming', 'tennis']

# %%
folder = 'badminton' # A separate folder for the sport. 
file = 'badminton.csv' # .csv file that contains the list of URLs of the images. 

path = Path('data/sports')
dest = path/folder #Path to download images in. 
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400) # command to download images. 
download_images(path/file, dest, max_pics=20, max_workers=0) #To ensure there wer no problems while downloading.

# %%
folder = 'baseball'
file = 'baseball.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'basketball'
file = 'basketball.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'cricket'
file = 'cricket.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'football'
file = 'football.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'golf'
file = 'golf.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'hockey'
file = 'hockey.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'squash'
file = 'squash.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'swimming'
file = 'swimming.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
folder = 'tennis'
file = 'tennis.csv'

path = Path('data/sports')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

download_images(path/file, dest, max_pics=400)
download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
path.ls()
# Out:
# [PosixPath('data/sports/golf'),
#  PosixPath('data/sports/golf.csv'),
#  PosixPath('data/sports/cricket.csv'),
#  PosixPath('data/sports/squash'),
#  PosixPath('data/sports/cleaned.csv'),
#  PosixPath('data/sports/hockey.csv'),
#  PosixPath('data/sports/tennis'),
#  PosixPath('data/sports/badminton.csv'),
#  PosixPath('data/sports/squash.csv'),
#  PosixPath('data/sports/baseball.csv'),
#  PosixPath('data/sports/hockey'),
#  PosixPath('data/sports/baseball'),
#  PosixPath('data/sports/cricket'),
#  PosixPath('data/sports/basketball.csv'),
#  PosixPath('data/sports/export.pkl'),
#  PosixPath('data/sports/swimming.csv'),
#  PosixPath('data/sports/.ipynb_checkpoints'),
#  PosixPath('data/sports/tennis.csv'),
#  PosixPath('data/sports/models'),
#  PosixPath('data/sports/football.csv'),
#  PosixPath('data/sports/basketball'),
#  PosixPath('data/sports/football'),
#  PosixPath('data/sports/swimming'),
#  PosixPath('data/sports/badminton')]

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# badminton
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='370' class='' max='370', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [370/370 00:00<00:00]
#     </div>
# baseball
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='382' class='' max='382', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [382/382 00:00<00:00]
#     </div>
# basketball
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='383' class='' max='383', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [383/383 00:00<00:00]
#     </div>
# cricket
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='365' class='' max='365', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [365/365 00:00<00:00]
#     </div>
# football
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='392' class='' max='392', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [392/392 00:00<00:00]
#     </div>
# golf
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='371' class='' max='371', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [371/371 00:00<00:00]
#     </div>
# hockey
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='379' class='' max='379', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [379/379 00:00<00:00]
#     </div>
# squash
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='362' class='' max='362', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [362/362 00:00<00:00]
#     </div>
# swimming
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='374' class='' max='374', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [374/374 00:00<00:00]
#     </div>
# tennis
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='377' class='' max='377', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [377/377 00:00<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['badminton',
#  'baseball',
#  'basketball',
#  'cricket',
#  'football',
#  'golf',
#  'hockey',
#  'sports',
#  'squash',
#  'swimming',
#  'tennis']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['badminton',
#   'baseball',
#   'basketball',
#   'cricket',
#   'football',
#   'golf',
#   'hockey',
#   'sports',
#   'squash',
#   'swimming',
#   'tennis'],
#  11,
#  3006,
#  751)

# %% [markdown]
# ## Train model

# %% [markdown]
# I train a CNN resnet34 for this task.

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 01:05 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.487279</td>
#       <td>0.469679</td>
#       <td>0.138482</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.784357</td>
#       <td>0.352490</td>
#       <td>0.109188</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.535846</td>
#       <td>0.306639</td>
#       <td>0.102530</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.395276</td>
#       <td>0.291030</td>
#       <td>0.093209</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# A 9.3% Error by running only 4 cycles and basically not doing anything is pretty impressive. Let's save this model.

# %%
learn.save('stage-1')

# %% [markdown]
# Time to see if Hyperparameter tuning would be useful for this problem.

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(6, max_lr=slice(1e-5,1e-3))
# Out:
# Total time: 02:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.263235</td>
#       <td>0.252048</td>
#       <td>0.083888</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.229758</td>
#       <td>0.249485</td>
#       <td>0.078562</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.182720</td>
#       <td>0.217773</td>
#       <td>0.071904</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.125622</td>
#       <td>0.179401</td>
#       <td>0.053262</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.087902</td>
#       <td>0.172818</td>
#       <td>0.050599</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.067645</td>
#       <td>0.167896</td>
#       <td>0.049268</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# A 4.9% Error just by Hyperparameter tuning and using only 400 images each! Wow! We save our model.

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# Looks like our model fitted Grass layouts for golf and hard and shiny courts for squash. Seems pretty reasonable as we trained with less than 400 images only while traditional tasks are trained on milliond of images. Also, there was mislabelled image in the squash dataset which our classifier correctly identified. Win for us!

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='47' class='' max='47', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [47/47 00:25<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Now, we load the cleaned data.

# %%
np.random.seed(42)
data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# ## Putting the model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# We revert back to using CPU for inference.

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'jordan.jpg')
img
# Out:
# Image (3, 327, 580)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, just make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class.obj
# Out:
# 'basketball'

# %% [markdown]
# ### Perfect! Looks like a classifier works well! So, here's my challenge. Find any image for the 10 sports classified here and my classifier will probably get this right more than 95% of the time.
